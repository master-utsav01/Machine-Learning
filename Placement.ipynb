# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as mlt 
import seaborn as sb

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
mlt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 59   4.8  112.0
# 20   6.6  120.0
# 64   7.0   64.0
# 11   6.9  138.0
# 12   5.4  139.0
# ..   ...    ...
# 68   4.0   75.0
# 39   4.6  146.0
# 86   5.1  128.0
# 72   7.3  116.0
# 73   4.9   61.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 59    0
# 20    1
# 64    1
# 11    1
# 12    0
#      ..
# 68    0
# 39    0
# 86    0
# 72    1
# 73    0
# Name: placement, Length: 90, dtype: int64

# %%
 x_test
# Out:
#     cgpa     iq
# 74   6.7  154.0
# 22   4.9  120.0
# 62   6.0  102.0
# 7    5.0   63.0
# 29   7.0  112.0
# 91   7.5  158.0
# 48   6.6  138.0
# 25   5.0   91.0
# 88   4.4  149.0
# 89   4.9  151.0

# %%
y_test
# Out:
# 74    1
# 22    0
# 62    0
# 7     0
# 29    1
# 91    1
# 48    1
# 25    0
# 88    0
# 89    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scale=StandardScaler()

x_train= scale.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.05690016, -0.28409745],
#        [ 0.5124658 , -0.0874146 ],
#        [ 0.86121378, -1.46419453],
#        [ 0.77402679,  0.35512181],
#        [-0.53377817,  0.37970716],
#        [ 0.4252788 ,  0.89599963],
#        [ 0.2509048 , -0.50536565],
#        [-0.27221718,  1.11726784],
#        [-1.84158313, -0.35785351],
#        [-1.14408715, -0.06282924],
#        [-1.75439613, -0.57912172],
#        [ 1.99464475,  1.09268248],
#        [-0.18503018,  0.45346323],
#        [ 1.29714877, -1.53795059],
#        [ 0.4252788 ,  0.15843896],
#        [ 0.4252788 , -0.82497527],
#        [ 0.07653081, -0.50536565],
#        [-0.96971316,  1.78107245],
#        [ 0.2509048 ,  0.08468289],
#        [-1.14408715, -0.89873134],
#        [ 0.77402679, -0.67746314],
#        [-0.01065619,  0.01092682],
#        [ 0.4252788 , -2.12799913],
#        [ 1.12277478, -0.9233167 ],
#        [ 0.94840078,  0.67473143],
#        [ 0.68683979, -0.82497527],
#        [-0.96971316,  0.77307286],
#        [-0.53377817, -0.40702422],
#        [ 0.59965279,  1.43687746],
#        [-1.05690016,  0.9697557 ],
#        [ 1.38433577,  0.10926825],
#        [-0.18503018,  1.04351177],
#        [-1.05690016,  1.11726784],
#        [-0.53377817, -0.23492673],
#        [ 0.07653081,  0.20760967],
#        [ 0.77402679,  0.37970716],
#        [ 1.12277478, -1.80838951],
#        [-0.62096517, -0.23492673],
#        [-1.05690016,  0.42887787],
#        [-0.70815217, -0.82497527],
#        [-0.27221718,  0.20760967],
#        [-0.70815217,  0.20760967],
#        [-0.96971316,  0.25678038],
#        [ 0.3380918 , -0.18575602],
#        [ 0.68683979,  0.42887787],
#        [-0.27221718,  0.40429252],
#        [ 0.2509048 ,  0.10926825],
#        [-0.70815217,  0.92058499],
#        [-0.88252616, -0.13658531],
#        [ 0.07653081, -1.43960917],
#        [ 0.94840078, -1.85756022],
#        [-1.14408715, -1.7592188 ],
#        [-0.01065619, -1.93131629],
#        [ 0.16371781, -0.25951209],
#        [ 0.07653081,  0.79765821],
#        [ 1.82027075,  0.62556072],
#        [ 2.16901874, -0.0874146 ],
#        [-1.40564814, -2.00507235],
#        [ 1.73308376, -1.09541419],
#        [ 1.82027075,  1.04351177],
#        [-2.19033112,  2.69073061],
#        [-1.49283514,  1.87941387],
#        [ 0.86121378,  1.26477997],
#        [-0.27221718,  0.47804859],
#        [-0.70815217, -0.33326816],
#        [ 0.3380918 ,  0.42887787],
#        [-0.79533916, -1.41502381],
#        [ 0.86121378,  1.85482851],
#        [ 1.38433577, -0.84956063],
#        [-0.79533916,  1.28936533],
#        [ 1.29714877,  0.15843896],
#        [ 1.55870976, -0.23492673],
#        [ 0.86121378,  0.37970716],
#        [-0.01065619,  0.62556072],
#        [-2.36470511,  1.46146282],
#        [-0.01065619, -1.41502381],
#        [ 0.07653081, -1.04624348],
#        [-0.62096517, -0.06282924],
#        [ 0.68683979, -0.28409745],
#        [-0.53377817,  0.28136574],
#        [ 1.20996177,  0.20760967],
#        [ 0.68683979, -0.01365853],
#        [-0.70815217,  2.46946241],
#        [ 1.12277478,  0.33053645],
#        [-0.09784319, -0.43160958],
#        [-1.75439613, -1.19375561],
#        [-1.23127415,  0.55180465],
#        [-0.79533916,  0.10926825],
#        [ 1.12277478, -0.18575602],
#        [-0.96971316, -1.53795059]])

# %%
x_test=scale.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.59965279,  0.7484875 ],
#        [-0.96971316, -0.0874146 ],
#        [-0.01065619, -0.529951  ],
#        [-0.88252616, -1.48877988],
#        [ 0.86121378, -0.28409745],
#        [ 1.29714877,  0.84682892],
#        [ 0.5124658 ,  0.35512181],
#        [-0.88252616, -0.80038992],
#        [-1.40564814,  0.62556072],
#        [-0.96971316,  0.67473143]])

# %%
from sklearn.linear_model import LogisticRegression

lg=LogisticRegression()

lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, 0, 1, 1, 1, 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
# %pip install mlxtend
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train, y_train.values, clf=lg, legend=2)
# Out:
# Requirement already satisfied: mlxtend in /opt/anaconda3/lib/python3.14/site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (1.18.0)
# Requirement already satisfied: numpy>=2.3.5 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (3.11.0)
# Requirement already satisfied: joblib>=1.5.2 in /opt/anaconda3/lib/python3.14/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/anaconda3/lib/python3.14/site-packages (from scikit-learn>=1.8.0->mlxtend) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/anaconda3/lib/python3.14/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# <Axes: >

# %%
import pickle

# %%
model=pickle.dump(lg,open('model.pkl','wb'))

# %%
print(model)
# Out:
# LogisticRegression()
